# %%
def hpr(cap1,i):#cap1,
    #cap1 = cv2.VideoCapture('rtsp://admin:admin123@192.168.199.67:554/cam/realmonitor?channel={}&subtype=0&unicast=true&proto=Onvif'.format(i))
    #print(cap1.get(7))
    #cap1.set(7,2)
    #print(cap1.get(7))
    if not cap1.isOpened():
            has_frame1 = False
            
    else:
        has_frame1, frame1 = cap1.read()
    while has_frame1:
        #has_frame1, frame1 = cap1.read()
        #while not has_frame1:
        out1 = HyperLPR_PlateRecogntion(frame1)
        if len(out1)>0:#,len(out2)
            if len(out1[0])>0:#,len(out2[0])
                if (out1[0][1])>0.95:#,(out2[0][1])
                    if (len(out1[0][0]))==7:#,(len(out2[0][0]))

                        #print('id1'+out1[0][0])
                        #print('id2'+out2[0][0])
                        localtime = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())
                        #print ("本地时间为 :", localtime)
                        #rts = rtsp[65:67]
                        #if rtsp[66]=='&':
                            #rts = rtsp[65]
            
                        data = 'id{}'.format(i),'hz001',out1,localtime
                        #data = str('id'+rtsp[65]+str(out)+str(localtime))
                        #print(data)
                        data2 = str(data)
                        s.sendto(data2.encode(),('192.168.199.237',1717))#78,1712
                        print(data2)
                            #print(s.recv(1024))
                        s.close
        #continue
        #sleep(1)
        break#  !!!  # yin wei shi while,continue 语句跳出本次循环，hai zai while nei,而break跳出整个(while)循环。
    
    
import cv2
from hyperlpr import *
import time
from time import sleep

import socket
s = socket.socket(socket.AF_INET,socket.SOCK_DGRAM)


cap1 = cv2.VideoCapture('rtsp://admin:admin123@192.168.199.67:554/cam/realmonitor?channel=1&subtype=0&unicast=true&proto=Onvif')
cap2 = cv2.VideoCapture('rtsp://admin:admin123@192.168.199.67:554/cam/realmonitor?channel=2&subtype=0&unicast=true&proto=Onvif')
#cap3 = cv2.VideoCapture('rtsp://admin:admin123@192.168.199.67:554/cam/realmonitor?channel=3&subtype=0&unicast=true&proto=Onvif')
#cap4 = cv2.VideoCapture('rtsp://admin:admin123@192.168.199.67:554/cam/realmonitor?channel=4&subtype=0&unicast=true&proto=Onvif')
#cap5 = cv2.VideoCapture('rtsp://admin:admin123@192.168.199.67:554/cam/realmonitor?channel=5&subtype=0&unicast=true&proto=Onvif')


while True:
    hpr(cap1,1)
    hpr(cap2,2)
    #for i in [1,2]:
        #hpr(i)
        
    #hpr(cap1,1)
    #hpr(cap2,2)
    #hpr(cap3,3)
    #hpr(cap4,4)
    #hpr(cap5,5)
    #ipid = [1,2,3]#,4,5
    #for i in ipid: 
        #hpr(i)
        #break
        #continue
        #p = multiprocessing.Process(target=hpr,args=(i,))
        #p.start()
# Out:
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.9772601638381858, [487, 493, 799, 576]]], '2019-04-24 11:27:10')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9740022846491498, [268, 121, 708, 237]]], '2019-04-24 11:27:10')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.9770740440774027, [489, 493, 796, 574]]], '2019-04-24 11:27:10')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9686670303206345, [266, 118, 711, 236]]], '2019-04-24 11:27:10')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.9716533081733315, [487, 492, 796, 575]]], '2019-04-24 11:27:10')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9761826821596472, [262, 119, 718, 239]]], '2019-04-24 11:27:10')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.9765523161067419, [485, 493, 799, 576]]], '2019-04-24 11:27:10')
# -9.223372036854776e+18
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.9714400853290744, [485, 492, 794, 575]]], '2019-04-24 11:27:10')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9764521036689774, [276, 120, 704, 233]]], '2019-04-24 11:27:10')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.9781136001719662, [485, 493, 794, 576]]], '2019-04-24 11:27:10')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9749563676831066, [240, 115, 712, 239]]], '2019-04-24 11:27:10')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.9780984861370412, [485, 493, 794, 576]]], '2019-04-24 11:27:10')
# -9.223372036854776e+18
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.
]], '2019-04-24 11:27:13')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9709711415288361, [257, 119, 701, 237]]], '2019-04-24 11:27:13')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.9726952399387367, [483, 493, 792, 576]]], '2019-04-24 11:27:13')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9732948371203208, [263, 121, 709, 239]]], '2019-04-24 11:27:13')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.975078846713169, [477, 492, 797, 577]]], '2019-04-24 11:27:13')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9748374223569843, [264, 119, 725, 241]]], '2019-04-24 11:27:13')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.969990542942904, [481, 493, 796, 577]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9738885334420723, [248, 117, 710, 239]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.979265017154873, [482, 493, 797, 577]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9680327943254872, [261, 118, 716, 238]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.9767399941032384, [486, 495, 786, 574]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9741961444988044, [260, 120, 719, 242]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.9760285104884633, [486, 494, 789, 573]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9744890417232265, [260, 119, 716, 239]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.979113902350471, [487, 494, 790, 573]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9759829299651093, [256, 120, 716, 242]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.9780096581864286, [490, 494, 796, 575]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9733284285951259, [265, 123, 701, 238]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.9741385238372059, [490, 494, 796, 575]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9706674218039129, [262, 121, 714, 240]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.9752007382117329, [481, 492, 799, 576]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9744617938856153, [264, 122, 701, 238]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.9764528104097654, [482, 492, 800, 576]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.974845537103623, [263, 121, 711, 240]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.9783395869251542, [483, 493, 796, 576]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9748717120576282, [261, 121, 714, 241]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id1', 'hz001', [['皖AE887X', 0.972984416130335, [484, 493, 798, 576]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ('id2', 'hz001', [['鲁Q77777', 0.9725676519391222, [258, 119, 718, 241]]], '2019-04-24 11:27:14')
# -9.223372036854776e+18
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-7ddf02f88634> in <module>()
#      56
#      57 while True:
# ---> 58     hpr(cap1,1)
#      59     hpr(cap2,2)
#      60     #for i in [1,2]:
#
# <ipython-input-1-7ddf02f88634> in hpr(cap1, i)
#      12         #has_frame1, frame1 = cap1.read()
#      13         #while not has_frame1:
# ---> 14         out1 = HyperLPR_PlateRecogntion(frame1)
#      15         if len(out1)>0:#,len(out2)
#      16             if len(out1[0])>0:#,len(out2[0])
#
# ~/anaconda3/lib/python3.6/site-packages/hyperlpr/__init__.py in HyperLPR_PlateRecogntion(Input_BGR, minSize, charSelectionDeskew)
#      11
#      12 def HyperLPR_PlateRecogntion(Input_BGR,minSize=30,charSelectionDeskew=True):
# ---> 13     return PR.plateRecognition(Input_BGR,minSize,charSelectionDeskew)
#      14
#      15
#
# ~/anaconda3/lib/python3.6/site-packages/hyperlpr/hyperlpr.py in plateRecognition(self, image, minSize, charSelectionDeskew)
#     187
#     188
# --> 189         images = self.detectPlateRough(image,image.shape[0],minSize=minSize)
#     190         res_set = []
#     191         for j,plate in enumerate(images):
#
# ~/anaconda3/lib/python3.6/site-packages/hyperlpr/hyperlpr.py in detectPlateRough(self, image_gray, resize_h, en_scale, minSize)
#      44         :return:   the results.
#      45         """
# ---> 46         watches = self.detector.detectMultiScale(image_gray, en_scale, 3, minSize=(minSize*4, minSize))
#      47         cropped_images = []
#      48         for (x, y, w, h) in watches:
#
# KeyboardInterrupt:

# %%
#cap = cv2.VideoCapture('rtsp://admin:admin123@192.168.199.67:554/cam/realmonitor?channel=1&subtype=0&unicast=true&proto=Onvif')
cap = cv2.VideoCapture('subway.mp4')
#cap1.get(3)
ret = cap.set(cv2.CAP_PROP_FRAME_WIDTH,640)
print(ret)
cap.get(3)
# Out:
# False
# 1920.0
